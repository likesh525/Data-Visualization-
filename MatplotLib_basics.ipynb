# %% [markdown]
# <a href="https://colab.research.google.com/github/likesh525/Data-Visualization-/blob/main/MatplotLib_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pip install openpyxl - for python to read excel files
import pandas as pd
import numpy as np
df_can = pd.read_excel(r'C:\Users\mla3kor\Desktop\Canada.xlsx',
    sheet_name='Canada by Citizenship',
    skiprows=range(20),
    skipfooter=2) # spedicifing the sheet and rows to be skipped


print('Data read into a pandas dataframe!')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-450c551f8a1d> in <module>()
#       5     sheet_name='Canada by Citizenship',
#       6     skiprows=range(20),
# ----> 7     skipfooter=2) # spedicifing the sheet and rows to be skipped
#       8
#       9
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df_can.info(verbose = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2619d79be6b2> in <module>()
# ----> 1 df_can.info(verbose = False)
#
# NameError: name 'df_can' is not defined

# %%
print(type(df_can.columns))
print(type(df_can.index))

# %%
df_can.drop(['AREA','REG','DEV','Type','Coverage'], axis=1 , inplace = True)# axis '0', implies row, axis '1', implies column
df_can.head()
